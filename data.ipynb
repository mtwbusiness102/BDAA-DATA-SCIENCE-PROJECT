# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sb
import plotly.express as px
import folium

# Delcare the path to the CSV file
path = "Latest_Data_Breahces.csv"

# Call pandas method to read the CSV file
dataset = pd.read_csv(path)

# Display the dataset
display(dataset)

###
# Out:
#                     organisation  \
# 0                Shanghai Police
# 1                           CDEK
# 2                           Plex
# 3                     FlexBooker
# 4                        PayHere
# ..                           ...
# 412    Automatic Data Processing
# 413  Cardsystems Solutions Inc.
# 414                    Citigroup
# 415              Ameritrade Inc.
# 416                          AOL
#
#                                       alternative name records lost  year     \
# 0                                                  NaN  500,000,000     2022
# 1                                                  NaN   18,218,203     2022
# 2                                                  NaN   15,000,000     2022
# 3                                                  NaN    3,700,000     2022
# 4                                                  NaN    1,580,249     2022
# ..                                                 ...          ...      ...
# 412           Business outsourcing, payrolls, benefits      125,000     2006
# 413  Third-party payment processor for Visa, Master...   40,000,000     2005
# 414                                                NaN    3,900,000     2005
# 415                                      online broker      200,000     2005
# 416                                    American Online   92,000,000     2004
#
#           date                                              story     sector  \
# 0       22-Jul  A database containing records of over a billio...  financial
# 1       22-Mar  UNVERIFIED. Russian courier service CDEK was h...     retail
# 2       22-Aug  Intruders access password data, usernames, and...       web
# 3       22-Jan                     appointment scheduling service        web
# 4       22-Mar  Sri Lankan payment gateway PayHere suffered a ...  financial
# ..         ...                                                ...        ...
# 412   Jul 2006  Automatic Data Processing, one of the world's ...    finance
# 413   Jun 2005  An unauthorized entity enabled access to cusom...    finance
# 414   Jun 2005  A box of computer tapes containing information...    finance
# 415   Apr 2005  A computer backup tape containing the personal...    finance
# 416   Jun 2004  A former America Online software engineer stol...        web
#
#             method interesting story  data sensitivity displayed records  \
# 0           hacked               NaN               5.0     "one billion"
# 1           hacked               NaN               3.0        19,000,000
# 2           hacked               NaN               1.0               NaN
# 3           hacked               NaN               3.0         3,700,000
# 4           hacked               NaN               3.0               NaN
# ..             ...               ...               ...               ...
# 412  poor security               NaN               2.0               NaN
# 413         hacked                 y               3.0               NaN
# 414   lost device                  y               3.0               NaN
# 415   lost device                NaN               2.0               NaN
# 416     inside job               NaN               1.0        92,000,000
#
#      Unnamed: 11        source name  \
# 0            NaN       The Register
# 1            NaN  Have I Been Pwned
# 2            NaN       Ars technica
# 3            NaN  Bleeping Computer
# 4            NaN           Pay Here
# ..           ...                ...
# 412          NaN           ABC News
# 413          NaN              Wired
# 414          NaN           NY Times
# 415          NaN                NBC
# 416          NaN                CNN
#
#                                        1st source link 2nd source link   ID
# 0    https://www.theregister.com/2022/07/05/shangha...             NaN  420
# 1    https://twitter.com/haveibeenpwned/status/1504...             NaN  413
# 2    https://arstechnica.com/information-technology...             NaN  418
# 3    https://www.bleepingcomputer.com/news/security...             NaN  409
# 4    https://blog.payhere.lk/ensuring-integrity-on-...             NaN  414
# ..                                                 ...             ...  ...
# 412  http://abcnews.go.com/Technology/story?id=2160...             NaN    8
# 413  https://www.wired.com/2005/06/cardsystems-data...             NaN    3
# 414  http://www.nytimes.com/2005/06/07/business/07d...             NaN    4
# 415                 http://www.nbcnews.com/id/7561268/             NaN    5
# 416  http://money.cnn.com/2004/06/23/technology/aol...             NaN    2
#
# [417 rows x 16 columns]
