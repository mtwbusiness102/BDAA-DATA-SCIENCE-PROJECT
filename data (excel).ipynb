# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb 
import plotly.express as px
import folium

# Delcare the path to the CSV file
path = "Latest_Data_Breahces.xlsx"

# Call pandas method to read the CSV file
dataset = pd.read_excel(path)

# Display the dataset
display(dataset)
# Out:
#                Organization  Records Lost  Year          Date  \
# 0                   "Apple"      12367232     2012   Mar 2012
# 1                     500px      14800000     2019   Feb 2019
# 2                      8fit      20000000     2019   Feb 2019
# 3                   Aadhaar     550000000     2018   Mar 2018
# 4    Accendo Insurance Co.         175350     2011   Jun 2011
# ..                      ...           ...      ...        ...
# 412                  YouNow      40000000     2019   Feb 2019
# 413                  Zappos      24000000     2012   Jan 2012
# 414                 Zhenhua       2400000     2020   Sep 2020
# 415                  Zomato      17000000     2017   May 2017
# 416                    Zoom        500000     2020   Apr 2020
#
#                                                  Story        Sector  \
# 0    Millions of Apple Unique Device Identifiers (U...  tech, retail
# 1    A July 2018 hack exposed the personal informat...           web
# 2    Part of the theft of 617 million online accoun...           web
# 3    India's biometric database was breached via a ...    government
# 4    Mismailed letters allowed some lines of sensit...       health
# ..                                                 ...           ...
# 412  Part of the theft of 127 million online accoun...           web
# 413  The Amazon-owned e-commerce firm was the targe...           web
# 414  Personal details of millions of notable people...          misc
# 415  Stolen email addresses and hashed passwords we...           web
# 416  Email addresses, passwords and personal meetin...           app
#
#             Method Interesting Story  Data Sensitivity Displayed Records  \
# 0            oops!                 y               2.0               NaN
# 1           hacked               NaN               2.0               NaN
# 2           hacked               NaN               1.0               NaN
# 3    poor security               NaN               4.0        1100000000
# 4    poor security               NaN               2.0               NaN
# ..             ...               ...               ...               ...
# 412         hacked               NaN               1.0               NaN
# 413         hacked               NaN               2.0               NaN
# 414          oops!                 y               1.0               NaN
# 415         hacked               NaN               4.0               NaN
# 416         hacked               NaN               1.0            500000
#
#           Source Name
# 0                CNET
# 1           PetaPixel
# 2        The Register
# 3               ZDNet
# 4       Data Breaches
# ..                ...
# 412        Techcrunch
# 413            Forbes
# 414      The Guardian
# 415          HackRead
# 416  We Live Security
#
# [417 rows x 11 columns]
